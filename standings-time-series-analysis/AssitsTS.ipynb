# %%
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.dates as mdates
import datetime as DT
# %matplotlib inline
import os

# %%
dirpath ='/Users/abhinay/Documents/cs/projects/fantasy-hockey-analytics/standings-snapshot-analysis/data-files'
list_files = os.listdir(dirpath) # dir is your directory path
number_files = len(list_files)

# %%
datelist = pd.date_range("2017-10-17", periods=number_files-1).tolist()
dates = list((dobj.date().strftime('%Y-%m-%d') for dobj in datelist))
stats = pd.DataFrame()

# %%
for date in dates:
    path ='~/Documents/cs/projects/fantasy-hockey-analytics/standings-snapshot-analysis/data-files/{}.csv'.format(date)
    frame = pd.read_csv(path)
    # Renaming the columns for clarity
    frame.rename(columns={'GP*.1': 'GoalieGP', 'GP*': 'PlayerGP'}, inplace=True)
    frame['date'] = date
    stats = pd.concat([stats, frame], ignore_index=True)

# %%
PlayerAssits = pd.DataFrame()
for name in stats['Team Name'].unique():
    df = stats[stats['Team Name']== name][['date','A']]
    df.set_index(df['date'], inplace=True)
    df.drop('date', axis=1, inplace=True)
    df.rename(columns={'A':name}, inplace=True)
    PlayerAssits=pd.concat([PlayerAssits, df], axis=1)

PlayerAssits
# Out:
#             /u/BuffaloSobbers1  /u/xskilledsnipax  /u/Hotwired38  /u/canadaq  \
# date
# 2017-10-17                  21                 40             42          30
# 2017-10-18                  28                 44             51          35
# 2017-10-19                  28                 44             53          37
# 2017-10-20                  29                 47             58          40
#
#             /u/crayfishparty2  /u/joey3140  /u/TheManagement  /u/Dangled0re  \
# date
# 2017-10-17                 39           47                25             27
# 2017-10-18                 43           51                28             31
# 2017-10-19                 43           52                28             36
# 2017-10-20                 47           58                28             38
#
#             /u/xprmnts  /u/acegfx  /u/scomar201  /u/rjupp24  /u/flykessel  \
# date
# 2017-10-17          40         28            31          42            29
# 2017-10-18          41         29            37          45            33
# 2017-10-19          43         31            39          46            33
# 2017-10-20          43         36            43          50            33
#
#             Huge's Real Gud Pros  /u/mcgrevin  /u/phoninghome  /u/Truxa  \
# date
# 2017-10-17                    22           30              37        27
# 2017-10-18                    25           37              42        32
# 2017-10-19                    26           39              42        34
# 2017-10-20                    28           44              42        36
#
#             /u/idrisk2000  u/ctrl_alt_karma  /u/ninjaemperor
# date
# 2017-10-17             29                20               25
# 2017-10-18             36                25               30
# 2017-10-19             36                26               30
# 2017-10-20             47                27               33

# %%
x = [DT.datetime.strptime(d,'%Y-%m-%d').date() for d in dates]


plt.gca().xaxis.set_major_formatter(mdates.DateFormatter('%m/%d/%Y'))
plt.gca().xaxis.set_major_locator(mdates.DayLocator())
for name in PlayerAssits.columns:
    if name == '/u/xprmnts':
        plt.plot(x,PlayerAssits[name],'r-',lw=4,)
    else:
        plt.plot(x,PlayerAssits[name],'grey')
plt.legend(bbox_to_anchor=(1.1, 1.05))
plt.gcf().autofmt_xdate()
plt.tight_layout()
